# %%
# Import the dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    country = citipy.nearest_city(coordinate[0], coordinate[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather"

# Create a list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
        
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of the Set 1 | la asuncion
# Processing Record 2 of the Set 1 | atuona
# Processing Record 3 of the Set 1 | qaanaaq
# Processing Record 4 of the Set 1 | port alfred
# Processing Record 5 of the Set 1 | puerto ayora
# Processing Record 6 of the Set 1 | cabo san lucas
# Processing Record 7 of the Set 1 | kodiak
# Processing Record 8 of the Set 1 | adrar
# Processing Record 9 of the Set 1 | san quintin
# Processing Record 10 of the Set 1 | avarua
# Processing Record 11 of the Set 1 | sao filipe
# Processing Record 12 of the Set 1 | saskylakh
# Processing Record 13 of the Set 1 | butaritari
# Processing Record 14 of the Set 1 | mendahara
# City not found. Skipping...
# Processing Record 15 of the Set 1 | barrow
# Processing Record 16 of the Set 1 | tura
# Processing Record 17 of the Set 1 | aksu
# Processing Record 18 of the Set 1 | aurdal
# Processing Record 19 of the Set 1 | rikitea
# Processing Record 20 of the Set 1 | banda aceh
# City not found. Skipping...
# Processing Record 21 of the Set 1 | mazatlan
# Processing Record 22 of the Set 1 | evensk
# Processing Record 23 of the Set 1 | albany
# Processing Record 24 of the Set 1 | dingle
# Processing Record 25 of the Set 1 | falmouth
# Processing Record 26 of the Set 1 | asau
# Processing Record 27 of the Set 1 | mahibadhoo
# Processing Record 28 of the Set 1 | alfredo baquerizo moreno
# Processing Record 29 of the Set 1 | hermanus
# Processing Record 30 of the Set 1 | bluff
# Processing Record 31 of the Set 1 | franklin
# Processing Record 32 of the Set 1 | jamestown
# Processing Record 33 of the Set 1 | kapaa
# Processing Record 34 of the Set 1 | chivay
# Processing Record 35 of the Set 1 | narsaq
# Processing Record 36 of the Set 1 | derzhavinsk
# Processing Record 37 of the Set 1 | port lincoln
# Processing Record 38 of the Set 1 | maputo
# Processing Record 39 of the Set 1 | port hawkesbury
# Processing Record 40 of the Set 1 | husavik
# Processing Record 41 of the Set 1 | arcachon
# Processing Record 42 of the Set 1 | mindelo
# Processing Record 43 of the Set 1 | samusu
# Processing Record 44 of the Set 1 | vaini
# Processing Record 45 of the Set 1 | artyk
# Processing Record 46 of the Set 1 | bethel
# Processing Record 47 of the Set 1 | sur
# Processing Record 48 of the Set 1 | ust-ordynskiy
# Processing Record 49 of the Set 1 | baykit
# Processing Record 50 of the Set 1 | vardo
# Processing Record 1 of the Set 2 | saint-pierre
# Processing Record 2 of the Set 2 | kiama
# Processing Record 3 of the Set 2 | caribou
# Processing Record 4 of the Set 2 | ust-karsk
# Processing Record 5 of the Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 6 of the Set 2 | mount isa
# Processing Record 7 of the Set 2 | ushuaia
# Processing Record 8 of the Set 2 | entre rios
# Processing Record 9 of the Set 2 | hobart
# Processing Record 10 of the Set 2 | college
# Processing Record 11 of the Set 2 | san patricio
# Processing Record 12 of the Set 2 | itarema
# Processing Record 13 of the Set 2 | dikson
# Processing Record 14 of the Set 2 | vao
# Processing Record 15 of the Set 2 | copacabana
# Processing Record 16 of the Set 2 | hilo
# Processing Record 17 of the Set 2 | cherskiy
# Processing Record 18 of the Set 2 | broome
# Processing Record 19 of the Set 2 | zhigansk
# Processing Record 20 of the Set 2 | grand gaube
# Processing Record 21 of the Set 2 | atikokan
# Processing Record 22 of the Set 2 | krasnoyarsk
# Processing Record 23 of the Set 2 | mataura
# Processing Record 24 of the Set 2 | miragoane
# Processing Record 25 of the Set 2 | thompson
# Processing Record 26 of the Set 2 | katsuura
# Processing Record 27 of the Set 2 | belmonte
# Processing Record 28 of the Set 2 | sambava
# Processing Record 29 of the Set 2 | geraldton
# Processing Record 30 of the Set 2 | fort nelson
# Processing Record 31 of the Set 2 | provideniya
# Processing Record 32 of the Set 2 | soe
# City not found. Skipping...
# Processing Record 33 of the Set 2 | balkanabat
# Processing Record 34 of the Set 2 | bayan
# Processing Record 35 of the Set 2 | ancud
# Processing Record 36 of the Set 2 | portland
# Processing Record 37 of the Set 2 | tasiilaq
# Processing Record 38 of the Set 2 | boende
# Processing Record 39 of the Set 2 | marsa matruh
# Processing Record 40 of the Set 2 | tutoia
# Processing Record 41 of the Set 2 | punta arenas
# Processing Record 42 of the Set 2 | zheleznogorsk-ilimskiy
# Processing Record 43 of the Set 2 | kernersville
# Processing Record 44 of the Set 2 | isla mujeres
# Processing Record 45 of the Set 2 | lara
# Processing Record 46 of the Set 2 | mahebourg
# Processing Record 47 of the Set 2 | codrington
# Processing Record 48 of the Set 2 | georgetown
# Processing Record 49 of the Set 2 | mildura
# Processing Record 50 of the Set 2 | kuala terengganu
# Processing Record 1 of the Set 3 | biak
# City not found. Skipping...
# Processing Record 2 of the Set 3 | talalayivka
# Processing Record 3 of the Set 3 | guelengdeng
# City not found. Skipping...
# Processing Record 4 of the Set 3 | ilulissat
# Processing Record 5 of the Set 3 | yellowknife
# Processing Record 6 of the Set 3 | busselton
# Processing Record 7 of the Set 3 | makakilo city
# Processing Record 8 of the Set 3 | iqaluit
# Processing Record 9 of the Set 3 | saint anthony
# Processing Record 10 of the Set 3 | tucuma
# Processing Record 11 of the Set 3 | kumluca
# Processing Record 12 of the Set 3 | nizhneyansk
# Processing Record 13 of the Set 3 | alofi
# Processing Record 14 of the Set 3 | luderitz
# Processing Record 15 of the Set 3 | caibarien
# Processing Record 16 of the Set 3 | bengkulu
# City not found. Skipping...
# Processing Record 17 of the Set 3 | taolanaro
# Processing Record 18 of the Set 3 | pangnirtung
# Processing Record 19 of the Set 3 | kailua
# Processing Record 20 of the Set 3 | new norfolk
# Processing Record 21 of the Set 3 | nuuk
# Processing Record 22 of the Set 3 | anadyr
# Processing Record 23 of the Set 3 | tautira
# Processing Record 24 of the Set 3 | atar
# Processing Record 25 of the Set 3 | norman wells
# Processing Record 26 of the Set 3 | petropavlovsk-kamchatskiy
# Processing Record 27 of the Set 3 | esso
# Processing Record 28 of the Set 3 | pisco
# Processing Record 29 of the Set 3 | cache creek
# Processing Record 30 of the Set 3 | kuito
# Processing Record 31 of the Set 3 | porto novo
# Processing Record 32 of the Set 3 | yomitan
# Processing Record 33 of the Set 3 | malwan
# Processing Record 34 of the Set 3 | ponta do sol
# Processing Record 35 of the Set 3 | saint-philippe
# Processing Record 36 of the Set 3 | cape town
# Processing Record 37 of the Set 3 | mehamn
# Processing Record 38 of the Set 3 | castro
# Processing Record 39 of the Set 3 | chuguyevka
# Processing Record 40 of the Set 3 | tokur
# Processing Record 41 of the Set 3 | sampit
# City not found. Skipping...
# Processing Record 42 of the Set 3 | bakchar
# Processing Record 43 of the Set 3 | lorengau
# Processing Record 44 of the Set 3 | chicama
# Processing Record 45 of the Set 3 | nizwa
# Processing Record 46 of the Set 3 | dabola
# Processing Record 47 of the Set 3 | victoria
# Processing Record 48 of the Set 3 | linqu
# Processing Record 49 of the Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 50 of the Set 3 | severo-kurilsk
# Processing Record 1 of the Set 4 | grand centre
# Processing Record 2 of the Set 4 | leningradskiy
# Processing Record 3 of the Set 4 | krasnoarmeysk
# Processing Record 4 of the Set 4 | amahai
# City not found. Skipping...
# Processing Record 5 of the Set 4 | mathbaria
# Processing Record 6 of the Set 4 | kimbe
# Processing Record 7 of the Set 4 | paita
# Processing Record 8 of the Set 4 | megion
# Processing Record 9 of the Set 4 | tuktoyaktuk
# Processing Record 10 of the Set 4 | vila franca do campo
# Processing Record 11 of the Set 4 | bisira
# Processing Record 12 of the Set 4 | oksfjord
# Processing Record 13 of the Set 4 | hofn
# Processing Record 14 of the Set 4 | hithadhoo
# Processing Record 15 of the Set 4 | khatanga
# Processing Record 16 of the Set 4 | morondava
# Processing Record 17 of the Set 4 | amderma
# Processing Record 18 of the Set 4 | carnarvon
# Processing Record 19 of the Set 4 | juifang
# City not found. Skipping...
# Processing Record 20 of the Set 4 | kpalime
# Processing Record 21 of the Set 4 | touros
# Processing Record 22 of the Set 4 | halalo
# City not found. Skipping...
# Processing Record 23 of the Set 4 | illoqqortoormiut
# Processing Record 24 of the Set 4 | kysyl-syr
# Processing Record 25 of the Set 4 | kaitangata
# Processing Record 26 of the Set 4 | tsihombe
# Processing Record 27 of the Set 4 | upington
# Processing Record 28 of the Set 4 | kununurra
# Processing Record 29 of the Set 4 | rusetu
# Processing Record 30 of the Set 4 | biltine
# City not found. Skipping...
# Processing Record 31 of the Set 4 | ulaanbaatar
# Processing Record 32 of the Set 4 | lebu
# Processing Record 33 of the Set 4 | diamantino
# Processing Record 34 of the Set 4 | bulungu
# Processing Record 35 of the Set 4 | kloulklubed
# Processing Record 36 of the Set 4 | thinadhoo
# Processing Record 37 of the Set 4 | barvinkove
# Processing Record 38 of the Set 4 | lata
# Processing Record 39 of the Set 4 | ambilobe
# Processing Record 40 of the Set 4 | chuy
# Processing Record 41 of the Set 4 | xining
# Processing Record 42 of the Set 4 | aneho
# Processing Record 43 of the Set 4 | fortuna
# Processing Record 44 of the Set 4 | cayenne
# Processing Record 45 of the Set 4 | viligili
# Processing Record 46 of the Set 4 | nanortalik
# Processing Record 47 of the Set 4 | george
# Processing Record 48 of the Set 4 | cabedelo
# Processing Record 49 of the Set 4 | esna
# Processing Record 50 of the Set 4 | vostok
# Processing Record 1 of the Set 5 | fairbanks
# Processing Record 2 of the Set 5 | calabozo
# Processing Record 3 of the Set 5 | kizukuri
# Processing Record 4 of the Set 5 | rawannawi
# Processing Record 5 of the Set 5 | pacific grove
# Processing Record 6 of the Set 5 | obilnoye
# Processing Record 7 of the Set 5 | labuhan
# City not found. Skipping...
# Processing Record 8 of the Set 5 | bredasdorp
# Processing Record 9 of the Set 5 | kichmengskiy gorodok
# Processing Record 10 of the Set 5 | tiksi
# Processing Record 11 of the Set 5 | klaksvik
# Processing Record 12 of the Set 5 | chokurdakh
# Processing Record 13 of the Set 5 | maun
# Processing Record 14 of the Set 5 | nicholasville
# Processing Record 15 of the Set 5 | airai
# Processing Record 16 of the Set 5 | beloha
# Processing Record 17 of the Set 5 | brokopondo
# Processing Record 18 of the Set 5 | upernavik
# Processing Record 19 of the Set 5 | gorno-chuyskiy
# Processing Record 20 of the Set 5 | sitka
# Processing Record 21 of the Set 5 | portobelo
# Processing Record 22 of the Set 5 | khormuj
# City not found. Skipping...
# Processing Record 23 of the Set 5 | east london
# Processing Record 24 of the Set 5 | moose factory
# Processing Record 25 of the Set 5 | adiake
# Processing Record 26 of the Set 5 | bambous virieux
# Processing Record 27 of the Set 5 | ostrovnoy
# Processing Record 28 of the Set 5 | nenjiang
# Processing Record 29 of the Set 5 | zhongshu
# Processing Record 30 of the Set 5 | valparaiso
# Processing Record 31 of the Set 5 | brae
# Processing Record 32 of the Set 5 | hualmay
# Processing Record 33 of the Set 5 | hasaki
# Processing Record 34 of the Set 5 | nicoya
# Processing Record 35 of the Set 5 | mizan teferi
# Processing Record 36 of the Set 5 | chumikan
# Processing Record 37 of the Set 5 | kajaani
# Processing Record 38 of the Set 5 | masterton
# Processing Record 39 of the Set 5 | price
# Processing Record 40 of the Set 5 | port hardy
# Processing Record 41 of the Set 5 | puno
# Processing Record 42 of the Set 5 | orchard homes
# Processing Record 43 of the Set 5 | te anau
# Processing Record 44 of the Set 5 | abu kamal
# Processing Record 45 of the Set 5 | apricena
# Processing Record 46 of the Set 5 | tambopata
# Processing Record 47 of the Set 5 | sorland
# Processing Record 48 of the Set 5 | vaitape
# Processing Record 49 of the Set 5 | westpunt
# City not found. Skipping...
# Processing Record 50 of the Set 5 | yar-sale
# Processing Record 1 of the Set 6 | ouadda
# Processing Record 2 of the Set 6 | komsomolskiy
# Processing Record 3 of the Set 6 | mehriz
# City not found. Skipping...
# Processing Record 4 of the Set 6 | dali
# Processing Record 5 of the Set 6 | warmbad
# Processing Record 6 of the Set 6 | sao joao da barra
# Processing Record 7 of the Set 6 | quelimane
# Processing Record 8 of the Set 6 | kamenka
# Processing Record 9 of the Set 6 | borba
# Processing Record 10 of the Set 6 | kasangulu
# Processing Record 11 of the Set 6 | tuatapere
# Processing Record 12 of the Set 6 | kathu
# Processing Record 13 of the Set 6 | karasjok
# Processing Record 14 of the Set 6 | arraial do cabo
# Processing Record 15 of the Set 6 | mantua
# Processing Record 16 of the Set 6 | zunyi
# Processing Record 17 of the Set 6 | maumere
# City not found. Skipping...
# Processing Record 18 of the Set 6 | tabuk
# Processing Record 19 of the Set 6 | ylivieska
# Processing Record 20 of the Set 6 | warqla
# Processing Record 21 of the Set 6 | sept-iles
# Processing Record 22 of the Set 6 | bonfim
# Processing Record 23 of the Set 6 | betong
# Processing Record 24 of the Set 6 | minab
# City not found. Skipping...
# Processing Record 25 of the Set 6 | cabinda
# Processing Record 26 of the Set 6 | samarai
# Processing Record 27 of the Set 6 | panguna
# Processing Record 28 of the Set 6 | aban
# Processing Record 29 of the Set 6 | sakakah
# Processing Record 30 of the Set 6 | ust-nera
# Processing Record 31 of the Set 6 | krasnovishersk
# Processing Record 32 of the Set 6 | nikolayevsk-na-amure
# Processing Record 33 of the Set 6 | cuicatlan
# Processing Record 34 of the Set 6 | goderich
# Processing Record 35 of the Set 6 | port blair
# Processing Record 36 of the Set 6 | ribeira grande
# Processing Record 37 of the Set 6 | port elizabeth
# Processing Record 38 of the Set 6 | seoul
# Processing Record 39 of the Set 6 | salalah
# Processing Record 40 of the Set 6 | payo
# Processing Record 41 of the Set 6 | sentyabrskiy
# Processing Record 42 of the Set 6 | jahangirabad
# Processing Record 43 of the Set 6 | harnoli
# Processing Record 44 of the Set 6 | ngunguru
# Processing Record 45 of the Set 6 | kropotkin
# Processing Record 46 of the Set 6 | grindavik
# Processing Record 47 of the Set 6 | bhuban
# Processing Record 48 of the Set 6 | mys shmidta
# Processing Record 49 of the Set 6 | coquimbo
# Processing Record 50 of the Set 6 | farah
# Processing Record 1 of the Set 7 | huadian
# Processing Record 2 of the Set 7 | srednekolymsk
# Processing Record 3 of the Set 7 | kruisfontein
# Processing Record 4 of the Set 7 | colesberg
# Processing Record 5 of the Set 7 | meulaboh
# City not found. Skipping...
# Processing Record 6 of the Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 7 of the Set 7 | kyren
# Processing Record 8 of the Set 7 | almeirim
# Processing Record 9 of the Set 7 | meyungs
# Processing Record 10 of the Set 7 | domoni
# Processing Record 11 of the Set 7 | muravlenko
# Processing Record 12 of the Set 7 | longyearbyen
# City not found. Skipping...
# Processing Record 13 of the Set 7 | monteiro
# Processing Record 14 of the Set 7 | dinsor
# City not found. Skipping...
# Processing Record 15 of the Set 7 | katobu
# City not found. Skipping...
# Processing Record 16 of the Set 7 | inirida
# Processing Record 17 of the Set 7 | dobronin
# Processing Record 18 of the Set 7 | tadine
# Processing Record 19 of the Set 7 | pavlodar
# Processing Record 20 of the Set 7 | maiduguri
# Processing Record 21 of the Set 7 | umzimvubu
# Processing Record 22 of the Set 7 | nove hrady
# Processing Record 23 of the Set 7 | marcona
# Processing Record 24 of the Set 7 | cidreira
# Processing Record 25 of the Set 7 | tilichiki
# Processing Record 26 of the Set 7 | nipawin
# Processing Record 27 of the Set 7 | qaqortoq
# Processing Record 28 of the Set 7 | mandalgovi
# Processing Record 29 of the Set 7 | gusinoye ozero
# Processing Record 30 of the Set 7 | mnogovershinnyy
# Processing Record 31 of the Set 7 | sataua
# Processing Record 32 of the Set 7 | antalaha
# Processing Record 33 of the Set 7 | semey
# Processing Record 34 of the Set 7 | saleaula
# Processing Record 35 of the Set 7 | benidorm
# Processing Record 36 of the Set 7 | stromness
# Processing Record 37 of the Set 7 | natchitoches
# Processing Record 38 of the Set 7 | qiyang
# Processing Record 39 of the Set 7 | benguela
# Processing Record 40 of the Set 7 | chitral
# Processing Record 41 of the Set 7 | patan
# Processing Record 42 of the Set 7 | broken hill
# Processing Record 43 of the Set 7 | kavieng
# Processing Record 44 of the Set 7 | zolotinka
# Processing Record 45 of the Set 7 | progreso
# Processing Record 46 of the Set 7 | herat
# Processing Record 47 of the Set 7 | polyarnyye zori
# Processing Record 48 of the Set 7 | pasco
# Processing Record 49 of the Set 7 | mocambique
# Processing Record 50 of the Set 7 | flin flon
# Processing Record 1 of the Set 8 | pajan
# Processing Record 2 of the Set 8 | rabo de peixe
# Processing Record 3 of the Set 8 | rantauprapat
# City not found. Skipping...
# Processing Record 4 of the Set 8 | jiddah
# Processing Record 5 of the Set 8 | cottonwood
# Processing Record 6 of the Set 8 | westport
# Processing Record 7 of the Set 8 | soyo
# Processing Record 8 of the Set 8 | peterhead
# Processing Record 9 of the Set 8 | aquiraz
# Processing Record 10 of the Set 8 | ndele
# Processing Record 11 of the Set 8 | la rioja
# Processing Record 12 of the Set 8 | viedma
# Processing Record 13 of the Set 8 | kavaratti
# Processing Record 14 of the Set 8 | ambon
# City not found. Skipping...
# Processing Record 15 of the Set 8 | constitucion
# Processing Record 16 of the Set 8 | ayr
# Processing Record 17 of the Set 8 | saint-joseph
# Processing Record 18 of the Set 8 | muros
# Processing Record 19 of the Set 8 | taltal
# Processing Record 20 of the Set 8 | kuche
# Processing Record 21 of the Set 8 | westport
# Processing Record 22 of the Set 8 | lavrentiya
# Processing Record 23 of the Set 8 | seravezza
# Processing Record 24 of the Set 8 | tieli
# Processing Record 25 of the Set 8 | ocos
# Processing Record 26 of the Set 8 | nome
# Processing Record 27 of the Set 8 | avera
# Processing Record 28 of the Set 8 | nizhnyaya poyma
# Processing Record 29 of the Set 8 | half moon bay
# Processing Record 30 of the Set 8 | kochki
# Processing Record 31 of the Set 8 | shelburne
# Processing Record 32 of the Set 8 | nemuro
# Processing Record 33 of the Set 8 | liwale
# Processing Record 34 of the Set 8 | ixtapa
# Processing Record 35 of the Set 8 | bilibino
# Processing Record 36 of the Set 8 | biu
# Processing Record 37 of the Set 8 | kemlya
# Processing Record 38 of the Set 8 | miechow
# Processing Record 39 of the Set 8 | barawe
# City not found. Skipping...
# Processing Record 40 of the Set 8 | puerto escondido
# Processing Record 41 of the Set 8 | ialibu
# Processing Record 42 of the Set 8 | terrace
# Processing Record 43 of the Set 8 | laurel
# Processing Record 44 of the Set 8 | beringovskiy
# Processing Record 45 of the Set 8 | nurota
# Processing Record 46 of the Set 8 | shimoda
# Processing Record 47 of the Set 8 | bilma
# Processing Record 48 of the Set 8 | birecik
# Processing Record 49 of the Set 8 | kudahuvadhoo
# Processing Record 50 of the Set 8 | sopiste
# City not found. Skipping...
# Processing Record 1 of the Set 9 | mount gambier
# Processing Record 2 of the Set 9 | saldanha
# Processing Record 3 of the Set 9 | tlahualilo
# Processing Record 4 of the Set 9 | aasiaat
# Processing Record 5 of the Set 9 | capalnita
# Processing Record 6 of the Set 9 | souillac
# Processing Record 7 of the Set 9 | alice springs
# Processing Record 8 of the Set 9 | atherton
# Processing Record 9 of the Set 9 | kichera
# Processing Record 10 of the Set 9 | kinshasa
# Processing Record 11 of the Set 9 | kahului
# Processing Record 12 of the Set 9 | karratha
# Processing Record 13 of the Set 9 | bandarbeyla
# City not found. Skipping...
# Processing Record 14 of the Set 9 | hambantota
# Processing Record 15 of the Set 9 | attawapiskat
# Processing Record 16 of the Set 9 | northam
# Processing Record 17 of the Set 9 | mackay
# Processing Record 18 of the Set 9 | bargal
# City not found. Skipping...
# Processing Record 19 of the Set 9 | guerrero negro
# Processing Record 20 of the Set 9 | gamba
# Processing Record 21 of the Set 9 | muskego
# Processing Record 22 of the Set 9 | kampot
# Processing Record 23 of the Set 9 | mana
# Processing Record 24 of the Set 9 | basco
# Processing Record 25 of the Set 9 | nikolskoye
# Processing Record 26 of the Set 9 | acurenam
# Processing Record 27 of the Set 9 | saint george
# Processing Record 28 of the Set 9 | huarmey
# Processing Record 29 of the Set 9 | faanui
# Processing Record 30 of the Set 9 | north ogden
# Processing Record 31 of the Set 9 | mujiayingzi
# Processing Record 32 of the Set 9 | dandong
# Processing Record 33 of the Set 9 | conceicao da barra
# Processing Record 34 of the Set 9 | tabas
# City not found. Skipping...
# Processing Record 35 of the Set 9 | bereznik
# Processing Record 36 of the Set 9 | dzerzhinskoye
# Processing Record 37 of the Set 9 | chapais
# Processing Record 38 of the Set 9 | puerto baquerizo moreno
# Processing Record 39 of the Set 9 | awbari
# Processing Record 40 of the Set 9 | honningsvag
# Processing Record 41 of the Set 9 | pangody
# Processing Record 42 of the Set 9 | hokitika
# Processing Record 43 of the Set 9 | ponta do sol
# Processing Record 44 of the Set 9 | lazaro cardenas
# Processing Record 45 of the Set 9 | jumla
# Processing Record 46 of the Set 9 | mattru
# Processing Record 47 of the Set 9 | faya
# City not found. Skipping...
# Processing Record 48 of the Set 9 | muncar
# City not found. Skipping...
# Processing Record 49 of the Set 9 | dukat
# Processing Record 50 of the Set 9 | hay river
# Processing Record 1 of the Set 10 | anito
# Processing Record 2 of the Set 10 | caravelas
# Processing Record 3 of the Set 10 | camacupa
# Processing Record 4 of the Set 10 | lasa
# Processing Record 5 of the Set 10 | nanakuli
# Processing Record 6 of the Set 10 | sjenica
# Processing Record 7 of the Set 10 | gornopravdinsk
# Processing Record 8 of the Set 10 | bozoum
# Processing Record 9 of the Set 10 | tubuala
# Processing Record 10 of the Set 10 | skalistyy
# Processing Record 11 of the Set 10 | ahuimanu
# Processing Record 12 of the Set 10 | mubende
# Processing Record 13 of the Set 10 | carlsbad
# Processing Record 14 of the Set 10 | gat
# Processing Record 15 of the Set 10 | grand river south east
# Processing Record 16 of the Set 10 | lagoa
# Processing Record 17 of the Set 10 | riberalta
# Processing Record 18 of the Set 10 | amapa
# Processing Record 19 of the Set 10 | hobyo
# City not found. Skipping...
# Processing Record 20 of the Set 10 | henties bay
# Processing Record 21 of the Set 10 | lodwar
# Processing Record 22 of the Set 10 | bubaque
# Processing Record 23 of the Set 10 | isangel
# Processing Record 24 of the Set 10 | abu samrah
# Processing Record 25 of the Set 10 | kendari
# City not found. Skipping...
# Processing Record 26 of the Set 10 | tarragona
# Processing Record 27 of the Set 10 | san cristobal
# Processing Record 28 of the Set 10 | sola
# Processing Record 29 of the Set 10 | bolitoc
# Processing Record 30 of the Set 10 | kouango
# Processing Record 31 of the Set 10 | oktyabrskiy
# Processing Record 32 of the Set 10 | belushya guba
# Processing Record 33 of the Set 10 | havoysund
# Processing Record 34 of the Set 10 | pevek
# Processing Record 35 of the Set 10 | guaruja
# Processing Record 36 of the Set 10 | crestview
# Processing Record 37 of the Set 10 | honiara
# Processing Record 38 of the Set 10 | big rapids
# Processing Record 39 of the Set 10 | namibe
# Processing Record 40 of the Set 10 | clyde river
# Processing Record 41 of the Set 10 | loubomo
# Processing Record 42 of the Set 10 | guiyang
# Processing Record 43 of the Set 10 | plettenberg bay
# Processing Record 44 of the Set 10 | wembley
# Processing Record 45 of the Set 10 | poindimie
# Processing Record 46 of the Set 10 | kortkeros
# Processing Record 47 of the Set 10 | hamilton
# Processing Record 48 of the Set 10 | hillsborough
# Processing Record 49 of the Set 10 | hami
# Processing Record 50 of the Set 10 | banepa
# Processing Record 1 of the Set 11 | nambour
# Processing Record 2 of the Set 11 | smithers
# Processing Record 3 of the Set 11 | muroto
# Processing Record 4 of the Set 11 | shitanjing
# Processing Record 5 of the Set 11 | ambulu
# Processing Record 6 of the Set 11 | rakovnik
# Processing Record 7 of the Set 11 | dengzhou
# Processing Record 8 of the Set 11 | tromso
# Processing Record 9 of the Set 11 | sao joaquim
# Processing Record 10 of the Set 11 | zvishavane
# Processing Record 11 of the Set 11 | zhuhai
# Processing Record 12 of the Set 11 | santa rosa
# Processing Record 13 of the Set 11 | phan rang
# City not found. Skipping...
# Processing Record 14 of the Set 11 | dakar
# Processing Record 15 of the Set 11 | limenaria
# Processing Record 16 of the Set 11 | dong hoi
# City not found. Skipping...
# Processing Record 17 of the Set 11 | hondo
# Processing Record 18 of the Set 11 | timaru
# Processing Record 19 of the Set 11 | teahupoo
# Processing Record 20 of the Set 11 | aden
# Processing Record 21 of the Set 11 | santiago de cuba
# Processing Record 22 of the Set 11 | luanda
# Processing Record 23 of the Set 11 | havre
# Processing Record 24 of the Set 11 | sharanga
# Processing Record 25 of the Set 11 | grafton
# Processing Record 26 of the Set 11 | lisakovsk
# Processing Record 27 of the Set 11 | sistranda
# Processing Record 28 of the Set 11 | piney green
# Processing Record 29 of the Set 11 | urdzhar
# Processing Record 30 of the Set 11 | cam pha
# City not found. Skipping...
# Processing Record 31 of the Set 11 | richards bay
# Processing Record 32 of the Set 11 | merauke
# Processing Record 33 of the Set 11 | letka
# Processing Record 34 of the Set 11 | abu dhabi
# Processing Record 35 of the Set 11 | ventspils
# Processing Record 36 of the Set 11 | kingskettle
# Processing Record 37 of the Set 11 | roald
# Processing Record 38 of the Set 11 | smolenka
# Processing Record 39 of the Set 11 | wuhan
# Processing Record 40 of the Set 11 | santo domingo xenacoj
# Processing Record 41 of the Set 11 | palabuhanratu
# Processing Record 42 of the Set 11 | kaeo
# Processing Record 43 of the Set 11 | shaunavon
# Processing Record 44 of the Set 11 | coihaique
# Processing Record 45 of the Set 11 | imbituba
# Processing Record 46 of the Set 11 | saint-francois
# Processing Record 47 of the Set 11 | sansai
# Processing Record 48 of the Set 11 | sibolga
# Processing Record 49 of the Set 11 | bhera
# Processing Record 50 of the Set 11 | challapata
# Processing Record 1 of the Set 12 | tawang
# Processing Record 2 of the Set 12 | ondjiva
# Processing Record 3 of the Set 12 | mont-dore
# Processing Record 4 of the Set 12 | minsk
# Processing Record 5 of the Set 12 | lensk
# Processing Record 6 of the Set 12 | trairi
# Processing Record 7 of the Set 12 | novaya ladoga
# Processing Record 8 of the Set 12 | taoudenni
# Processing Record 9 of the Set 12 | oistins
# Processing Record 10 of the Set 12 | porbandar
# Processing Record 11 of the Set 12 | palu
# Processing Record 12 of the Set 12 | magistralnyy
# Processing Record 13 of the Set 12 | ust-kamchatsk
# Processing Record 14 of the Set 12 | san alberto
# Processing Record 15 of the Set 12 | neiafu
# Processing Record 16 of the Set 12 | ossora
# Processing Record 17 of the Set 12 | sovetskiy
# Processing Record 18 of the Set 12 | waipawa
# Processing Record 19 of the Set 12 | edd
# Processing Record 20 of the Set 12 | strezhevoy
# Processing Record 21 of the Set 12 | north platte
# Processing Record 22 of the Set 12 | qeshm
# City not found. Skipping...
# Processing Record 23 of the Set 12 | lompoc
# Processing Record 24 of the Set 12 | pachino
# Processing Record 25 of the Set 12 | yongan
# Processing Record 26 of the Set 12 | keti bandar
# Processing Record 27 of the Set 12 | jiwani
# Processing Record 28 of the Set 12 | plainview
# Processing Record 29 of the Set 12 | camopi
# Processing Record 30 of the Set 12 | saryshagan
# Processing Record 31 of the Set 12 | cheuskiny
# Processing Record 32 of the Set 12 | labuan
# Processing Record 33 of the Set 12 | guozhen
# Processing Record 34 of the Set 12 | ayorou
# Processing Record 35 of the Set 12 | le vauclin
# Processing Record 36 of the Set 12 | iralaya
# Processing Record 37 of the Set 12 | giovinazzo
# Processing Record 38 of the Set 12 | sergeyevka
# Processing Record 39 of the Set 12 | ulaangom
# Processing Record 40 of the Set 12 | gori
# Processing Record 41 of the Set 12 | odweyne
# City not found. Skipping...
# Processing Record 42 of the Set 12 | uttarkashi
# Processing Record 43 of the Set 12 | filingue
# Processing Record 44 of the Set 12 | camacha
# Processing Record 45 of the Set 12 | nata
# Processing Record 46 of the Set 12 | beidao
# Processing Record 47 of the Set 12 | umm kaddadah
# Processing Record 48 of the Set 12 | talnakh
# Processing Record 49 of the Set 12 | ajaccio
# Processing Record 50 of the Set 12 | colares
# Processing Record 1 of the Set 13 | kodar
# Processing Record 2 of the Set 13 | san jose
# Processing Record 3 of the Set 13 | hammerfest
# Processing Record 4 of the Set 13 | san rafael
# Processing Record 5 of the Set 13 | breasta
# Processing Record 6 of the Set 13 | lapinig
# Processing Record 7 of the Set 13 | morris
# Processing Record 8 of the Set 13 | kasongo-lunda
# Processing Record 9 of the Set 13 | gotsu
# Processing Record 10 of the Set 13 | shorewood
# Processing Record 11 of the Set 13 | garowe
# City not found. Skipping...
# Processing Record 12 of the Set 13 | labutta
# City not found. Skipping...
# Processing Record 13 of the Set 13 | udachnyy
# Processing Record 14 of the Set 13 | kargasok
# Processing Record 15 of the Set 13 | marienburg
# Processing Record 16 of the Set 13 | paragominas
# Processing Record 17 of the Set 13 | naze
# Processing Record 18 of the Set 13 | heyang
# Processing Record 19 of the Set 13 | caluquembe
# Processing Record 20 of the Set 13 | kemin
# Processing Record 21 of the Set 13 | iseyin
# Processing Record 22 of the Set 13 | margate
# Processing Record 23 of the Set 13 | port augusta
# Processing Record 24 of the Set 13 | karaul
# Processing Record 25 of the Set 13 | safaqis
# City not found. Skipping...
# Processing Record 26 of the Set 13 | tanshui
# City not found. Skipping...
# Processing Record 27 of the Set 13 | balimo
# Processing Record 28 of the Set 13 | shakawe
# Processing Record 29 of the Set 13 | mumbwa
# Processing Record 30 of the Set 13 | olafsvik
# Processing Record 31 of the Set 13 | warri
# Processing Record 32 of the Set 13 | alta floresta
# Processing Record 33 of the Set 13 | santiago
# Processing Record 34 of the Set 13 | santa maria da vitoria
# Processing Record 35 of the Set 13 | chifeng
# Processing Record 36 of the Set 13 | teya
# Processing Record 37 of the Set 13 | quatre cocos
# Processing Record 38 of the Set 13 | tabou
# Processing Record 39 of the Set 13 | yenagoa
# Processing Record 40 of the Set 13 | whitianga
# Processing Record 41 of the Set 13 | pallasovka
# Processing Record 42 of the Set 13 | kuantan
# Processing Record 43 of the Set 13 | formoso do araguaia
# Processing Record 44 of the Set 13 | zhob
# Processing Record 45 of the Set 13 | salinas
# Processing Record 46 of the Set 13 | ijaki
# Processing Record 47 of the Set 13 | poum
# Processing Record 48 of the Set 13 | dembi dolo
# Processing Record 49 of the Set 13 | briancon
# Processing Record 50 of the Set 13 | acapulco
# Processing Record 1 of the Set 14 | torbay
# Processing Record 2 of the Set 14 | kalanguy
# Processing Record 3 of the Set 14 | shimanovsk
# Processing Record 4 of the Set 14 | port antonio
# Processing Record 5 of the Set 14 | mongoumba
# Processing Record 6 of the Set 14 | ingham
# Processing Record 7 of the Set 14 | orzhytsya
# Processing Record 8 of the Set 14 | bathsheba
# Processing Record 9 of the Set 14 | necochea
# Processing Record 10 of the Set 14 | saurimo
# Processing Record 11 of the Set 14 | lufilufi
# Processing Record 12 of the Set 14 | balabac
# Processing Record 13 of the Set 14 | sande
# Processing Record 14 of the Set 14 | cap malheureux
# Processing Record 15 of the Set 14 | banmo
# City not found. Skipping...
# Processing Record 16 of the Set 14 | mkushi
# Processing Record 17 of the Set 14 | melilla
# Processing Record 18 of the Set 14 | nchelenge
# Processing Record 19 of the Set 14 | minas
# Processing Record 20 of the Set 14 | bagan
# Processing Record 21 of the Set 14 | saint-augustin
# Processing Record 22 of the Set 14 | sobolevo
# Processing Record 23 of the Set 14 | guatire
# Processing Record 24 of the Set 14 | sorvag
# Processing Record 25 of the Set 14 | farafangana
# Processing Record 26 of the Set 14 | florianopolis
# Processing Record 27 of the Set 14 | marivan
# City not found. Skipping...
# Processing Record 28 of the Set 14 | da lat
# City not found. Skipping...
# Processing Record 29 of the Set 14 | upata
# Processing Record 30 of the Set 14 | velka bites
# Processing Record 31 of the Set 14 | malakal
# Processing Record 32 of the Set 14 | colombo
# Processing Record 33 of the Set 14 | albanel
# Processing Record 34 of the Set 14 | changying
# Processing Record 35 of the Set 14 | sao gabriel da cachoeira
# Processing Record 36 of the Set 14 | comodoro rivadavia
# Processing Record 37 of the Set 14 | dickinson
# Processing Record 38 of the Set 14 | nguiu
# Processing Record 39 of the Set 14 | buriti alegre
# Processing Record 40 of the Set 14 | antofagasta
# Processing Record 41 of the Set 14 | lindenhurst
# Processing Record 42 of the Set 14 | prince rupert
# Processing Record 43 of the Set 14 | pampas
# Processing Record 44 of the Set 14 | roebourne
# Processing Record 45 of the Set 14 | opuwo
# Processing Record 46 of the Set 14 | milingimbi
# Processing Record 47 of the Set 14 | vallentuna
# Processing Record 48 of the Set 14 | remanso
# Processing Record 49 of the Set 14 | buchanan
# Processing Record 50 of the Set 14 | mingaora
# Processing Record 1 of the Set 15 | the valley
# Processing Record 2 of the Set 15 | erenhot
# Processing Record 3 of the Set 15 | ketchikan
# Processing Record 4 of the Set 15 | petropavlovka
# Processing Record 5 of the Set 15 | lundazi
# Processing Record 6 of the Set 15 | mar del plata
# Processing Record 7 of the Set 15 | sug-aksy
# Processing Record 8 of the Set 15 | lingyuan
# Processing Record 9 of the Set 15 | churapcha
# Processing Record 10 of the Set 15 | manzil jamil
# City not found. Skipping...
# Processing Record 11 of the Set 15 | anzhero-sudzhensk
# Processing Record 12 of the Set 15 | onalaska
# Processing Record 13 of the Set 15 | pushkino
# Processing Record 14 of the Set 15 | puerto quijarro
# Processing Record 15 of the Set 15 | mananara
# Processing Record 16 of the Set 15 | benalla
# Processing Record 17 of the Set 15 | vyssi brod
# Processing Record 18 of the Set 15 | mareeba
# Processing Record 19 of the Set 15 | mbekenyera
# Processing Record 20 of the Set 15 | yako
# Processing Record 21 of the Set 15 | eyl
# City not found. Skipping...
# Processing Record 22 of the Set 15 | safaga
# Processing Record 23 of the Set 15 | noumea
# Processing Record 24 of the Set 15 | aklavik
# Processing Record 25 of the Set 15 | buala
# Processing Record 26 of the Set 15 | erzin
# Processing Record 27 of the Set 15 | krasnyy chikoy
# Processing Record 28 of the Set 15 | nizhniy odes
# Processing Record 29 of the Set 15 | khani
# Processing Record 30 of the Set 15 | altay
# Processing Record 31 of the Set 15 | simplicio mendes
# Processing Record 32 of the Set 15 | high rock
# Processing Record 33 of the Set 15 | xixiang
# Processing Record 34 of the Set 15 | victoria
# Processing Record 35 of the Set 15 | vanimo
# Processing Record 36 of the Set 15 | bulgan
# Processing Record 37 of the Set 15 | dayong
# Processing Record 38 of the Set 15 | jasidih
# Processing Record 39 of the Set 15 | byron bay
# Processing Record 40 of the Set 15 | utiroa
# Processing Record 41 of the Set 15 | bambanglipuro
# Processing Record 42 of the Set 15 | marystown
# Processing Record 43 of the Set 15 | narrabri
# Processing Record 44 of the Set 15 | magadan
# Processing Record 45 of the Set 15 | karoi
# Processing Record 46 of the Set 15 | raton
# Processing Record 47 of the Set 15 | umm lajj
# Processing Record 48 of the Set 15 | missoula
# Processing Record 49 of the Set 15 | akhtubinsk
# Processing Record 50 of the Set 15 | langxiang
# Processing Record 1 of the Set 16 | neijiang
# Processing Record 2 of the Set 16 | great yarmouth
# Processing Record 3 of the Set 16 | egvekinot
# Processing Record 4 of the Set 16 | llodio
# Processing Record 5 of the Set 16 | arlit
# Processing Record 6 of the Set 16 | nachalovo
# Processing Record 7 of the Set 16 | general roca
# Processing Record 8 of the Set 16 | malatya
# Processing Record 9 of the Set 16 | mayo
# Processing Record 10 of the Set 16 | takaka
# Processing Record 11 of the Set 16 | saint-honore
# Processing Record 12 of the Set 16 | porto walter
# Processing Record 13 of the Set 16 | parakou
# Processing Record 14 of the Set 16 | caucaia
# Processing Record 15 of the Set 16 | madera
# Processing Record 16 of the Set 16 | emerald
# Processing Record 17 of the Set 16 | changde
# Processing Record 18 of the Set 16 | gorodishche
# Processing Record 19 of the Set 16 | luganville
# Processing Record 20 of the Set 16 | lolua
# Processing Record 21 of the Set 16 | madruga
# Processing Record 22 of the Set 16 | gravdal
# Processing Record 23 of the Set 16 | la ronge
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Number of cities
len(city_data)
# Out:
# 724

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_weather_df = pd.DataFrame(city_data)
# Reorder the columns
city_weather_df=city_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_weather_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   La Asuncion      VE  11.0333  -63.8628     81.45        76          11
# 1        Atuona      PF  -9.8000 -139.0333     77.74        74           8
# 2       Qaanaaq      GL  77.4840  -69.3632     41.14        80         100
# 3   Port Alfred      ZA -33.5906   26.8910     56.17        97         100
# 4  Puerto Ayora      EC  -0.7393  -90.3518     78.76       100          94
#
#    Wind Speed Current Description
# 0       11.68          few clouds
# 1       15.12           clear sky
# 2        2.95     overcast clouds
# 3        1.99     overcast clouds
# 4        8.99     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the city_weather df into a CSV.
city_weather_df.to_csv(output_data_file, index_label="City_ID")
